# %% [markdown]
# # Entrada e saida de dados

# %%
import pandas as pd

# %%
df1 = pd.read_csv("datasets/exemplo.csv", sep=",", decimal=".")

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      float64
#  1   1       5 non-null      float64
#  2   2       5 non-null      float64
#  3   3       5 non-null      float64
# dtypes: float64(4)
# memory usage: 292.0 bytes

# %%
df1
# Out:
#           0         1         2         3
# 0 -0.394813 -0.694630  0.253393  0.602590
# 1 -2.134217  1.141381 -0.130142  0.690936
# 2 -0.223754  0.365133 -0.104233 -0.182788
# 3  0.108066  0.331332  0.053708 -0.280468
# 4  0.085290  0.740834 -0.596941  0.243950

# %% [markdown]
# # Excel

# %% [markdown]
# Pandas podem ler e escrever arquivos do Excel, tenha em mente, isso só importa dados. não fórmulas, gráficos, etc, lembrando que imagens ou macros podem bugar o metodo

# %% [markdown]
# bibliotecas necessárias para trabalhar com arquivos do Excel
# ```python
# pip install openpyxl
# pip install xlrd
# ```

# %% [markdown]
# ## Entrada via excel

# %%
pd.read_excel("Exemplo_Excel.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ## Saida via excel

# %%
df.to_excel("Exemplo_Excel.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ## HTML
#
# ### Entrada via HTML
# A função Pandas `read_html()` pode ser usada para ler tabelas de arquivos HTML. Ela retorna uma lista de DataFrames, um para cada tabela encontrada no arquivo HTML.

# %%
df = pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# 11                         First City Bank of Florida   Fort Walton Beach
# ...
