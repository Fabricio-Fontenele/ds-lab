# %%
import numpy as np
import pandas as pd

# %%
# Criando diferentes estruturas de dados para demonstrar a criação de Series

# Lista de rótulos/índices que serão usados nas Series
labels = ["a", "b", "c"]

# Lista Python simples com valores numéricos
minha_lista = [10, 20, 30]

# Array NumPy com os mesmos valores (estrutura mais eficiente para operações matemáticas)
arr = np.array([10, 20, 30])

# Dicionário Python (já possui chaves que servirão como índices)
d = {"a": 10, "b": 20, "c": 30}

# %% [markdown]
# ** Usando listas **

# %%
pd.Series(data=minha_lista)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=minha_lista, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(minha_lista, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ** NumPy Arrays **

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %% [markdown]
# ** Dicionários **

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### Dados nas Series
#
# Uma série de pandas pode conter uma variedade de tipos de objeto:

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
# Mesmo funções (embora seja improvável que você use isso)
pd.Series([sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# ## Usando um Índice
#
# A chave para usar uma Serie é entender seu índice. O Pandas faz uso desses nomes ou números de índice, permitindo pesquisas rápidas de informações (funciona como uma tabela de hash ou dicionário).
#
# Vamos ver alguns exemplos de como pegar informações de uma Serie. Vamos criar duas Series, ser1 e ser2:

# %%
ser1 = pd.Series([1, 2, 3, 4], index=["EUA", "Alemanha", "USSR", "Japão"])

# %%
ser1
# Out:
# EUA         1
# Alemanha    2
# USSR        3
# Japão       4
# dtype: int64

# %%
ser2 = pd.Series([1, 2, 5, 4], index=["EUA", "Alemanha", "Italia", "Japão"])

# %%
ser2
# Out:
# EUA         1
# Alemanha    2
# Italia      5
# Japão       4
# dtype: int64

# %%
ser1["EUA"]
# Out:
# 1

# %% [markdown]
# As operações também são feitas com base no índice:

# %%
ser1 + ser2
# Out:
# Alemanha    4.0
# EUA         2.0
# Italia      NaN
# Japão       8.0
# USSR        NaN
# dtype: float64
